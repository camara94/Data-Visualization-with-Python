# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_can = pd.read_csv('canada.csv')
df_can.head(2)
# Out:
#     Unnamed: 0 Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...  1223   856   702   560   716   561   539
#
#    2012  2013  Total
# 0  2635  2004  58639
# 1   620   603  15699
#
# [2 rows x 39 columns]

# %%
df_can.rename(columns={"Unnamed: 0": "Country"}, inplace=True)

# %%
df_can.index = df_can.iloc[:, 0]

# %%
years = list(map(str, range(1980, 2014)))

# %%
df_can.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# %%
top_5_countries = df_can.head()

# %%
top_5_countries = top_5_countries[years].transpose()
top_5_countries
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
top_5_countries.plot(kind='line')
plt.title('Immigration trend of top 5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')
