# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_can = pd.read_csv('canada.csv')
df_can.head(1)
# Out:
#     Unnamed: 0 Continent         Region             DevName  1980  1981  1982  \
# 0  Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#    1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203  2635
#
#    2013  Total
# 0  2004  58639
#
# [1 rows x 39 columns]

# %%
df_continent = df_can.groupby(['Continent'], axis=0).sum()
df_continent.head(3)
# Out:
#             1980   1981   1982   1983   1984   1985   1986   1987   1988  \
# Continent
# Africa      3951   4363   3819   2671   2639   2650   3782   7494   7552
# Asia       31025  34314  30214  24696  27274  23850  28739  43203  47454
# Europe     39760  44802  42720  24638  22287  20844  24370  46698  54726
#
#             1989  ...    2005    2006    2007    2008    2009    2010    2011  \
# Continent         ...
# Africa      9894  ...   27523   29188   28284   29890   34534   40892   35441
# Asia       60256  ...  159253  149054  133459  139894  141434  163845  146894
# Europe     60893  ...   35955   33053   33495   34692   35078   33425   26778
#
#              2012    2013    Total
# Continent
# Africa      38083   38543   618948
# Asia       152218  155075  3317794
# Europe      29177   28691  1410947
#
# [3 rows x 35 columns]

# %%
df_continent['Total'].plot(kind='pie', figsize=(10, 20))
# Out:
# <AxesSubplot:ylabel='Total'>
