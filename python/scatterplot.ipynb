# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_can = pd.read_csv('canada.csv')
df_can.head(3)
# Out:
#     Unnamed: 0 Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
# 2      Algeria    Africa  Northern Africa  Developing regions    80    67
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...  1223   856   702   560   716   561   539
# 2    71    69    63    44  ...  3626  4807  3623  4005  5393  4752  4325
#
#    2012  2013  Total
# 0  2635  2004  58639
# 1   620   603  15699
# 2  3774  4331  69439
#
# [3 rows x 39 columns]

# %%
years = list(map(str, range(1980, 2014)))
df_scatter = df_can.loc[:, years].transpose()
new_data = pd.DataFrame()
new_data['years'] = df_scatter.index  
new_data['Total'] = df_can['Total'][:]

# %%
new_data.head()
# Out:
#   years  Total
# 0  1980  58639
# 1  1981  15699
# 2  1982  69439
# 3  1983      6
# 4  1984     15

# %%
new_data.plot(kind='scater', x='years', y='Total')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-9a623644d5d5> in <module>
# ----> 1 new_data.plot(kind='scater', x='years', y='Total')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     880
#     881         if kind not in self._all_kinds:
# --> 882             raise ValueError(f"{kind} is not a valid plot kind")
#     883
#     884         # The original data structured can be transformed before passed to the
#
# ValueError: scater is not a valid plot kind
